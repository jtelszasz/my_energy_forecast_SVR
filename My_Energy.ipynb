# %% [markdown]
# # My BGE Smart Meter Data

# %%
import pandas as pd
import numpy as np
import import_funcs
#reload(import_funcs)

# %%
df_myBGEdata = import_funcs.BGEdata()

# %%
df_myBGEdata['USAGE'].hist(weights=np.ones_like(df_myBGEdata['USAGE'])/df_myBGEdata['USAGE'].size,bins=20)
xlim(xmax=max(df_myBGEdata['USAGE']))
ylabel('Probability')
xlabel('Usage (kWh)')

# %%
df_myBGEdata['USAGE'].hist(normed=1,cumulative=True,histtype='step',bins=200)
xlim(xmax=max(df_myBGEdata['USAGE']))
ylim(ymax=1)
ylabel('Probability')
xlabel('Usage (kWh)')
