# %% [markdown]
# # My BGE Smart Meter Data

# %%
import pandas as pd
import numpy as np
import import_funcs
#reload(import_funcs)

# %%
DF_myBGEdata = import_funcs.BGEdata()

# %%
FIG_ElecPDF = plt.figure()
PLT_ElecPDF = DF_myBGEdata['USAGE'].hist(weights=np.ones_like(df_myBGEdata['USAGE'])/df_myBGEdata['USAGE'].size,bins=20,grid=False)
xlim(xmax=max(df_myBGEdata['USAGE']))
ylabel('Probability')
xlabel('Usage (kWh)')

FIG_ElecPDF.savefig('ElecHist.png')

# %%
FIG_ElecCDF = plt.figure()
PLT_ElecCDF = df_myBGEdata['USAGE'].hist(normed=1,cumulative=True,histtype='step',bins=200)
xlim(xmax=max(df_myBGEdata['USAGE']))
ylim(ymax=1)
ylabel('Probability')
xlabel('Usage (kWh)')

FIG_ElecCDF.savefig('ElecCDF.png')

# %%
df_myBGEdata['USAGE']['2014-02-09':'2014-02-15'].plot()
